# %%
import numpy as np
import pandas as pd
import tushare as ts

# %%
stock1 = ts.get_hist_data('600848')  # 一次性获取全部日k线数据
stock1.shape
# Out:
# (644, 14)

# %%
stock2 = ts.get_hist_data('600898')  # 一次性获取全部日k线数据
stock2.shape
# Out:
# (612, 14)

# %%
stock1Price = stock1[["open","high","close","low"]].iloc[0:5]
stock1Price
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>close</th>
#       <th>low</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2018-03-23</th>
#       <td>25.20</td>
#       <td>25.49</td>
#       <td>23.93</td>
#       <td>23.93</td>
#     </tr>
#     <tr>
#       <th>2018-03-22</th>
#       <td>25.81</td>
#       <td>26.80</td>
#       <td>26.58</td>
#       <td>25.71</td>
#     </tr>
#     <tr>
#       <th>2018-03-21</th>
#       <td>26.45</td>
#       <td>27.12</td>
# ...

# %%
stock2Price = stock2[["open","high","close","low"]].iloc[0:5]
stock2Price
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>close</th>
#       <th>low</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2018-03-23</th>
#       <td>11.08</td>
#       <td>11.30</td>
#       <td>10.84</td>
#       <td>10.73</td>
#     </tr>
#     <tr>
#       <th>2018-03-22</th>
#       <td>11.66</td>
#       <td>11.75</td>
#       <td>11.57</td>
#       <td>11.28</td>
#     </tr>
#     <tr>
#       <th>2018-03-21</th>
#       <td>10.78</td>
#       <td>11.91</td>
# ...

# %%
pd.concat([stock1Price,stock2Price],axis=1)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>close</th>
#       <th>low</th>
#       <th>open</th>
#       <th>high</th>
#       <th>close</th>
#       <th>low</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2018-03-23</th>
#       <td>25.20</td>
#       <td>25.49</td>
#       <td>23.93</td>
#       <td>23.93</td>
#       <td>11.08</td>
#       <td>11.30</td>
#       <td>10.84</td>
#       <td>10.73</td>
# ...

# %%
pd.concat([stock1Price,stock2Price],keys=["600848","600898"])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>close</th>
#       <th>low</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="5" valign="top">600848</th>
#       <th>2018-03-23</th>
#       <td>25.20</td>
#       <td>25.49</td>
#       <td>23.93</td>
#       <td>23.93</td>
#     </tr>
#     <tr>
#       <th>2018-03-22</th>
#       <td>25.81</td>
#       <td>26.80</td>
#       <td>26.58</td>
#       <td>25.71</td>
#     </tr>
#     <tr>
# ...
