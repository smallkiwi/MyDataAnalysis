# %%
import numpy as np
import pandas as pd
import tushare as ts

# %%
df = ts.get_tick_data('600848',date='2014-01-09')
df.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>price</th>
#       <th>change</th>
#       <th>volume</th>
#       <th>amount</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>15:00:00</td>
#       <td>6.05</td>
#       <td>--</td>
#       <td>8</td>
#       <td>4840</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14:59:55</td>
#       <td>6.05</td>
#       <td>--</td>
#       <td>50</td>
#       <td>30250</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14:59:35</td>
#       <td>6.05</td>
#       <td>--</td>
# ...

# %%
df.shape
# Out:
# (515, 6)

# %%
df1 = df[["time","price"]].head(10)
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>15:00:00</td>
#       <td>6.05</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14:59:55</td>
#       <td>6.05</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14:59:35</td>
#       <td>6.05</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>14:59:30</td>
#       <td>6.05</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14:59:20</td>
#       <td>6.06</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>14:59:05</td>
#       <td>6.05</td>
#     </tr>
# ...

# %%
df2 = df[["time","type"]].head(10)
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>15:00:00</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14:59:55</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14:59:35</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>14:59:30</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14:59:20</td>
#       <td>买盘</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>14:59:05</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
# ...

# %%
pd.merge(df1,df2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>price</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>15:00:00</td>
#       <td>6.05</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14:59:55</td>
#       <td>6.05</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14:59:35</td>
#       <td>6.05</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>14:59:30</td>
#       <td>6.05</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14:59:20</td>
#       <td>6.06</td>
# ...
